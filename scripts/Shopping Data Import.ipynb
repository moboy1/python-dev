# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from urllib.parse import urlparse

#import urllib.request
#r = urllib.request.urlopen(url)
#data = r.read()

#from selenium import webdriver
#driver = webdriver.Chrome('C:/Users/mgaye_ext/node_modules/chromedriver/lib/chromedriver/chromedriver.exe')
#r = driver.get(url)
#data = driver.page_source


url="https://groceries.morrisons.com/browse/frozen-104162/ice-cream-168439"
parsed_url=urlparse(url)
url_home = '{uri.scheme}://{uri.netloc}/'.format(uri=parsed_url)[:-1]
r = requests.get(url)
data = r.text
html=BeautifulSoup(data, 'html')
product_listings=html.find_all("li", {"class": "fops-item"})

df=pd.DataFrame(columns=('product_image', 'product_description', 'product_on_offer', 'product_offer', 'product_weight', 'product_price', 'product_old_price', 'product_unit_price'))

i=0
for product_listing in product_listings:
#    if i<70: 
    product_offer=np.nan
    if product_listing.find("h4", class_="fop-title"):
        product_description=product_listing.find("h4", class_="fop-title").text
    if product_listing.find("img", class_="fop-img"):
        product_image=url_home + product_listing.find("img", class_="fop-img").attrs["src"]
    if product_listing.find("span", class_="fop-catch-weight"):
        product_weight=product_listing.find("span", class_="fop-catch-weight").text
    if product_listing.find("span", class_="fop-price"):
        product_price=product_listing.find("span", class_="fop-price").text
    if product_listing.find("span", class_="fop-old-price"):
        product_old_price=product_listing.find("span", class_="fop-old-price").text
    if product_listing.find("span", class_="fop-unit-price"):
        product_unit_price=product_listing.find("span", class_="fop-unit-price").text
    if product_listing.find("a", class_="fop-row-promo promotion-offer"):
        product_offer=product_listing.find("a", class_="fop-row-promo promotion-offer").span.text
    if pd.isna(product_offer):
        product_on_offer="N"
    else:
        product_on_offer="Y"

    df.loc[i] = [product_image, product_description, product_on_offer, product_offer, product_weight, product_price, product_old_price, product_unit_price]
    product_description, product_image, product_weight, product_price, product_old_price, product_unit_price, product_offer, product_on_offer = [np.nan] * 8
    
    i+=1
    
df=df.dropna(subset=['product_image', 'product_description', 'product_offer', 'product_weight', 'product_price', 'product_old_price', 'product_unit_price'], how='all')
df.to_csv("C:/Users/mgaye_ext/Work/training/python-dev/rawdata/morrisons_shopping2.csv")

df
# Out:
#                                          product_image  \
# 0    https://groceries.morrisons.com/productImages/...
# 1    https://groceries.morrisons.com/productImages/...
# 2    https://groceries.morrisons.com/productImages/...
# 3    https://groceries.morrisons.com/productImages/...
# 4    https://groceries.morrisons.com/productImages/...
# 5    https://groceries.morrisons.com/productImages/...
# 6    https://groceries.morrisons.com/productImages/...
# 7    https://groceries.morrisons.com/productImages/...
# 8    https://groceries.morrisons.com/productImages/...
# 9    https://groceries.morrisons.com/productImages/...
# 10   https://groceries.morrisons.com/productImages/...
# 11   https://groceries.morrisons.com/productImages/...
# 12   https://groceries.morrisons.com/productImages/...
# 13   https://groceries.morrisons.com/productImages/...
# 14   https://groceries.morrisons.com/productImages/...
# 15   https://groceries.morrisons.com/productImages/...
# 16   https://groceries.morrisons.com/productImages/...
# 17   https://groceries.morrisons.com/productImages/...
# 18   https://groceries.morrisons.com/productImages/...
# 19   https://groceries.morrisons.com/productImages/...
# 20   https://groceries.morrisons.com/productImages/...
# 21   https://groceries.morrisons.com/productImages/...
# 22   https://groceries.morrisons.com/productImages/...
# 23   https://groceries.morrisons.com/productImages/...
# 24   https://groceries.morrisons.com/productImages/...
# 25   https://groceries.morrisons.com/productImages/...
# 26   https://groceries.morrisons.com/productImages/...
# 27   https://groceries.morrisons.com/productImages/...
# 28   https://groceries.morrisons.com/productImages/...
# 29   https://groceries.morrisons.com/productImages/...
# 30   https://groceries.morrisons.com/productImages/...
# 31   https://groceries.morrisons.com/productImages/...
# 32   https://groceries.morrisons.com/productImages/...
# 33   https://groceries.morrisons.com/productImages/...
# 34   https://groceries.morrisons.com/productImages/...
# 35   https://groceries.morrisons.com/productImages/...
# 36   https://groceries.morrisons.com/productImages/...
# 37   https://groceries.morrisons.com/productImages/...
# 38   https://groceries.morrisons.com/productImages/...
# 39   https://groceries.morrisons.com/productImages/...
# 40   https://groceries.morrisons.com/productImages/...
# 41   https://groceries.morrisons.com/productImages/...
# 42   https://groceries.morrisons.com/productImages/...
# 43   https://groceries.morrisons.com/productImages/...
# 44   https://groceries.morrisons.com/productImages/...
# 45   https://groceries.morrisons.com/productImages/...
# 46   https://groceries.morrisons.com/productImages/...
# 47   https://groceries.morrisons.com/productImages/...
# 48   https://groceries.morrisons.com/productImages/...
# 49   https://groceries.morrisons.com/productImages/...
# 54   https://groceries.morrisons.com/productImages/...
# 65   https://groceries.morrisons.com/productImages/...
# 125  https://groceries.morrisons.com/productImages/...
# 140  https://groceries.morrisons.com/productImages/...
# 151  https://groceries.morrisons.com/productImages/...
# 167  https://groceries.morrisons.com/productImages/...
# 168  https://groceries.morrisons.com/productImages/...
# 186  https://groceries.morrisons.com/productImages/...
# 195  https://groceries.morrisons.com/productImages/...
#
#                                    product_description product_on_offer  \
# 0    Morrisons Low Calorie High Protein Salted Cara...                Y
# 1    Morrisons Low Calorie High Protein Choc Chip C...                Y
# 2    Morrisons Low Calorie High Protein Peanut Butt...                Y
# 3    Morrisons Green Apple & Pink Candyfloss Ice Cr...                Y
# 4     Morrisons The Best Salted Caramel Ice Cream500ml                N
# 5    Morrisons The Best Madagascan Vanilla Ice Crea...                N
# 6    Morrisons The Best Strawberry & Clotted Cream5...                N
# 7    Morrisons The Best Coconut Ice Lollies 4 Pack2...                N
# 8     Morrisons The Best Raspberry Lollies 4 Pack292ml                N
# 9    Morrisons The Best Valencia Orange Lollies 4 P...                N
# 10               Oxo SoftWorks Trigger Ice Cream Scoop                N
# 11   Twister Mini Pineapple, Lemon-Lime and Strawbe...                Y
# 12          Rowntree's Fruit Pastilles Lollies4 x 65ml                Y
# 13                     Mars 4 pack Ice Cream Bars204ml                Y
# 14                  Fab Ice Lollies Strawberry6 x 58ml                Y
# 15               Magnum White Chocolate & Cookies270ml                Y
# 16    Solero Exotic Explosion Ice Cream Sticks3 x 90ml                Y
# 17   Mini Milk Vanilla, Strawberry & Chocolate Ice ...                Y
# 18      Calippo Mini Orange & Lime Ice Lollies6 x 80ml                Y
# 19               Cadbury Dairy Milk Mini Cones8 x 25ml                Y
# 20                   Wall'S Cornetto 6 X Classico540ml                Y
# 21            Nestle Nobbly Bobbly Ice Lollies4 x 70ml                Y
# 22    Magnum Double Raspberry Ice Cream Sticks3 x 88ml                Y
# 23        Magnum Mini Classic Almond White 6 Pack330ml                Y
# 24                 Wall'S Cornetto 6 X Strawberry540ml                Y
# 25                    Nestle Smarties Cone    6 x 70ml                Y
# 26         Del Monte 100% Orange Juice Lollies3 x 75ml                Y
# 27                Rowntrees Watermelon Lollies4 x 73ml                Y
# 28           Haagen-Dazs Salted Caramel Ice Cream460ml                Y
# 29                             Feast Original X 4360ml                Y
# 31      Offer price £3, was £4.80          500ml         £3.00
# 32                   Buy 2 for £3          212ml         £2.00
# 33                   Buy 2 for £3          480ml         £2.00
# 34                   Buy 2 for £3       3 x 90ml         £2.00
# 35                   Buy 2 for £3      3 x 100ml         £2.00
# 36                   Buy 2 for £3          900ml         £2.00
# 37      Offer price £2, was £3.58       3 x 88ml         £2.00
# 38                   Buy 2 for £3          900ml         £2.00
# 39                   Buy 2 for £3      3 x 100ml         £2.00
# 40      Offer price £3, was £4.80          500ml         £3.00
# 41      Offer price £2, was £2.50          500ml         £2.00
# 42                   Buy 2 for £3          900ml         £2.00
# 43                   Buy 2 for £3          900ml         £2.00
# 44      Offer price £3, was £4.80          500ml         £3.00
# 45      Offer price £2, was £2.50          500ml         £2.00
# 46   Offer price £2.50, was £4.23          360ml         £2.50
# 47         Offer price £2, was £3          480ml         £2.00
# 48                   Buy 2 for £3          900ml         £2.00
# 49                   Buy 2 for £3          292ml         £2.00
# 54                   Buy 2 for £3          900ml         £2.00
# 65      Offer price £2, was £2.50          500ml         £2.00
# 125                           NaN          292ml         £2.00
# 140                           NaN          292ml         £2.00
# 151                           NaN          292ml         £2.00
# 167                           NaN          500ml         £2.85
# 168                           NaN          500ml         £2.85
# 186                           NaN          500ml         £2.85
# 195                           NaN                        £8.50
#
#     product_old_price product_unit_price
# 0               £2.50    £4.00 per litre
# 1               £2.50    £4.00 per litre
# 2               £2.50    £4.00 per litre
# 3                 NaN    22.2p per 100ml
# 4                 NaN      57p per 100ml
# 5                 NaN      57p per 100ml
# 6                 NaN      57p per 100ml
# 7                 NaN    68.5p per 100ml
# 8                 NaN    68.5p per 100ml
# 9                 NaN    68.5p per 100ml
# 10                NaN         £8.50 each
# 11                NaN      50p per 100ml
# 12                NaN    76.9p per 100ml
# 13                NaN      98p per 100ml
# 14                NaN    57.5p per 100ml
# 15              £3.50    74.3p per 100ml
# 16                NaN    74.1p per 100ml
# 17                NaN    51.7p per 100ml
# 18                NaN    41.7p per 100ml
# 19                NaN    £1.00 per 100ml
# 20                NaN      37p per 100ml
# 21                NaN    71.4p per 100ml
# 22              £3.58      76p per 100ml
# 23              £4.23    75.7p per 100ml
# 24                NaN      37p per 100ml
# 25                NaN    47.6p per 100ml
# 26                NaN    88.9p per 100ml
# 27                NaN    68.5p per 100ml
# 28              £4.42    54.4p per 100ml
# 29                NaN    55.6p per 100ml
# 30                NaN    22.2p per 100ml
# 31              £4.80      60p per 100ml
# 32                NaN    94.3p per 100ml
# 33                NaN    41.7p per 100ml
# 34                NaN    74.1p per 100ml
# 35                NaN    66.7p per 100ml
# 36                NaN    22.2p per 100ml
# 37              £3.58      76p per 100ml
# 38                NaN    22.2p per 100ml
# 39                NaN    66.7p per 100ml
# 40              £4.80      60p per 100ml
# 41              £2.50    £4.00 per litre
# 42                NaN    22.2p per 100ml
# 43                NaN    22.2p per 100ml
# 44              £4.80      60p per 100ml
# 45              £2.50    £4.00 per litre
# 46              £4.23        7p per 10ml
# 47              £3.00    41.7p per 100ml
# 48                NaN    22.2p per 100ml
# 49                NaN    68.5p per 100ml
# 54                NaN    22.2p per 100ml
# 65              £2.50    £4.00 per litre
# 125               NaN    68.5p per 100ml
# 140               NaN    68.5p per 100ml
# 151               NaN    68.5p per 100ml
# 167               NaN      57p per 100ml
# 168               NaN      57p per 100ml
# 186               NaN      57p per 100ml
# 195               NaN         £8.50 each
